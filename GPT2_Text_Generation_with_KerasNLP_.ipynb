# %% [markdown]
# <a href="https://colab.research.google.com/github/Itskedarjasud/Data-Dreamers-5201/blob/main/GPT2_Text_Generation_with_KerasNLP_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install KerasNLP
# !pip install git+https://github.com/keras-team/keras-nlp.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 61.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 42.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 53.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 39.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 21.6 MB/s eta 0:00:00
#   Building wheel for keras-nlp (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.1 which is incompatible.

# %%
# !pip uninstall tensorflow tf-keras -y
# Out:
# Found existing installation: tensorflow 2.16.1
# Uninstalling tensorflow-2.16.1:
#   Successfully uninstalled tensorflow-2.16.1
# Found existing installation: tf_keras 2.15.1
# Uninstalling tf_keras-2.15.1:
#   Successfully uninstalled tf_keras-2.15.1

# %%
# !pip install git+https://github.com/keras-team/keras-nlp.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# setting up your environment for using KerasNLP with a specified backend and mixed precision.

# backend
import os
os.environ["KERAS_BACKEND"] = "jax"  # or "tensorflow" or "torch"

# libraries
import keras_nlp #building and training NLP models
import keras #neural networks API providing a simple interface for building and training deep learning models
import tensorflow as tf #used for training and deploying machine learning models
import time #for handling time-related tasks

keras.mixed_precision.set_global_policy("mixed_float16")

# %% [markdown]
# # Introduction to Generative Large Language Models (LLMs)
#
# Large language models (LLMs) are advanced machine learning models trained on vast amounts of text data. They can perform tasks like generating text, answering questions, and translating languages.

# %%
#Load a pre-trained GPT-2 model and generate some text
preprocessor = keras_nlp.models.GPT2CausalLMPreprocessor.from_preset(
    "gpt2_base_en",
    sequence_length=128,
)
gpt2_lm = keras_nlp.models.GPT2CausalLM.from_preset(
    "gpt2_base_en", preprocessor=preprocessor
)

# this code sets up a GPT-2 model for text generation using KerasNLP. It first defines a preprocessor, which is responsible for
#     preparing the input text for the model. Then, it loads a pre-trained GPT-2 model with the specified preprocessor.
# Out:
# Downloading from https://www.kaggle.com/api/v1/models/keras/gpt2/keras/gpt2_base_en/2/download/metadata.json...
# 100%|██████████| 141/141 [00:00<00:00, 30.4kB/s]
# Downloading from https://www.kaggle.com/api/v1/models/keras/gpt2/keras/gpt2_base_en/2/download/preprocessor.json...
# Downloading from https://www.kaggle.com/api/v1/models/keras/gpt2/keras/gpt2_base_en/2/download/tokenizer.json...
# 100%|██████████| 448/448 [00:00<00:00, 303kB/s]
# Downloading from https://www.kaggle.com/api/v1/models/keras/gpt2/keras/gpt2_base_en/2/download/assets/tokenizer/vocabulary.json...
# 100%|██████████| 0.99M/0.99M [00:00<00:00, 2.43MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/keras/gpt2/keras/gpt2_base_en/2/download/assets/tokenizer/merges.txt...
# 100%|██████████| 446k/446k [00:00<00:00, 990kB/s]
# Downloading from https://www.kaggle.com/api/v1/models/keras/gpt2/keras/gpt2_base_en/2/download/task.json...
# Downloading from https://www.kaggle.com/api/v1/models/keras/gpt2/keras/gpt2_base_en/2/download/config.json...
# 100%|██████████| 484/484 [00:00<00:00, 1.18MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/keras/gpt2/keras/gpt2_base_en/2/download/model.weights.h5...
# 100%|██████████| 475M/475M [00:10<00:00, 48.1MB/s]

# %%
start = time.time()

output = gpt2_lm.generate("anurag is from latur ", max_length=200)
print("\nGPT-2 output:")
print(output)

end = time.time()
print(f"TOTAL TIME ELAPSED: {end - start:.2f}s")
# Out:
# GPT-2 output:
# anurag is from latur vernacular, and is the name of the first person plural of "anurag" (from anurag, from the root "an", from an, "to"). Anurag is from an, an, an, or a, which means "to" or "to the" (anurag). The root is from an, an, an, or an, which means "to" or "to the."
# TOTAL TIME ELAPSED: 9.70s

# %%
start = time.time()

output = gpt2_lm.generate("That Italian restaurant is", max_length=200)
print("\nGPT-2 output:")
print(output)

end = time.time()
print(f"TOTAL TIME ELAPSED: {end - start:.2f}s")
# Out:
# GPT-2 output:
# That Italian restaurant is the only place you can buy a sandwich with a cheese sandwich. The cheese sandwich was a big hit, and we were glad to see it. We also got a small selection of sandwiches, including sandwiches of the same type. The cheese sandwich had the best flavor we had ever had. I think it is a bit hard to describe the quality of this sandwich, as the cheese was pretty much the same as it is with a lot of other sandwich items. I think it is a bit hard to describe how much cheese this is made of, since we were eating here. The sandwich was good, and the service was good, too. The service here is good, and the sandwiches are great. The only thing I would change is that they had to change the prices on the menu. The prices were a bit high, but the sandwich was good for a small budget, and it had the same quality as it does with a lot of other sandwich items. We were very happy
# TOTAL TIME ELAPSED: 2.05s

# %%
start = time.time()

output = gpt2_lm.generate("the AI is the problem to", max_length=200)
print("\nGPT-2 output:")
print(output)

end = time.time()
print(f"TOTAL TIME ELAPSED: {end - start:.2f}s")
# Out:
# GPT-2 output:
# the AI is the problem to solve.
#
#
# The problem is that we can't solve the problem of what is wrong with the AI. It is a problem that needs solving.
#
#
# We can't do anything about it.
#
#
# It is the problem of what is wrong with the AI and what we can do about it.
#
#
# We can't solve it and we are stuck.
#
#
# We cannot do anything.
#
#
# I think that's the problem. I think there is a solution.
#
#
# I think that's the problem.
#
#
# There will be no solution.
#
#
# I think there's no solution.
#
#
# There is no solution.
#
#
# We have a problem.
#
#
# We have a problem.
#
#
# I think there is a solution.
#
#
# I think there is a solution.
#
#
# I believe we have a problem, we have problems, we have problems.
#
#
# We have problems, we have problems, we have problems.
#
#
# TOTAL TIME ELAPSED: 1.12s

# %%
start = time.time()

output = gpt2_lm.generate("The Tajmahal in India is", max_length=200)
print("\nGPT-2 output:")
print(output)

end = time.time()
print(f"TOTAL TIME ELAPSED: {end - start:.2f}s")
# Out:
# GPT-2 output:
# The Tajmahal in India is a beautiful place.
#
# The Tajmahal in India is a beautiful place.
#
# The Tajmahal in India is a beautiful place.
#
# The Tajmahal in India is beautiful place.
#
# The Tajmahal in India is a beautiful place.
#
# The Tajmahal in India is beautiful place.
#
# The Tajmahal in India is beautiful place.
#
# The Tajmahal in India is beautiful place.
#
# The Tajmahal in India is beautiful place.
#
# The Tajmahal in India is beautiful place.
#
# The Tajmahal in India is beautiful place.
# TOTAL TIME ELAPSED: 1.93s

# %%
import tensorflow_datasets as tfds

# Load the IMDB dataset
imdb_ds, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
train_ds, test_ds = imdb_ds['train'], imdb_ds['test']
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.3Y99JT_1.0.0/imdb_reviews-train.tfrecor…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.3Y99JT_1.0.0/imdb_reviews-test.tfrecord…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.3Y99JT_1.0.0/imdb_reviews-unsupervised.…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Tokenizer parameters
vocab_size = 10000
oov_token = '<OOV>'
max_length = 256
trunc_type = 'post'
padding_type = 'post'

# Initialize the tokenizer
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)

# Extract texts and labels
train_texts = []
train_labels = []
test_texts = []
test_labels = []

for text, label in tfds.as_numpy(train_ds):
    train_texts.append(text.decode('utf-8'))
    train_labels.append(label)

for text, label in tfds.as_numpy(test_ds):
    test_texts.append(text.decode('utf-8'))
    test_labels.append(label)

# Fit the tokenizer on training texts
tokenizer.fit_on_texts(train_texts)

# Convert texts to sequences
train_sequences = tokenizer.texts_to_sequences(train_texts)
test_sequences = tokenizer.texts_to_sequences(test_texts)

# Pad the sequences
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_padded, train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_padded, test_labels))

# Shuffle and batch the dataset
batch_size = 32
train_dataset = train_dataset.shuffle(buffer_size=10000).batch(batch_size, drop_remainder=True)
test_dataset = test_dataset.batch(batch_size, drop_remainder=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, GlobalAveragePooling1D

# Model parameters
embedding_dim = 64
lstm_units = 64

# Build the model
model = Sequential([
    Embedding(vocab_size, embedding_dim, input_length=max_length),

    LSTM(lstm_units),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_dataset, validation_data=test_dataset, epochs=10)
# Out:
# Epoch 1/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 49s 61ms/step - accuracy: 0.5261 - loss: nan - val_accuracy: 0.6086 - val_loss: nan
# Epoch 2/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.6240 - loss: nan - val_accuracy: 0.6086 - val_loss: nan
# Epoch 3/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.5811 - loss: nan - val_accuracy: 0.5001 - val_loss: nan
# Epoch 4/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 61s 79ms/step - accuracy: 0.5044 - loss: nan - val_accuracy: 0.5001 - val_loss: nan
# Epoch 5/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.5015 - loss: nan - val_accuracy: 0.5001 - val_loss: nan
# Epoch 6/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 43s 56ms/step - accuracy: 0.4982 - loss: nan - val_accuracy: 0.5001 - val_loss: nan
# Epoch 7/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 54s 70ms/step - accuracy: 0.5008 - loss: nan - val_accuracy: 0.5001 - val_loss: nan
# Epoch 8/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 61s 79ms/step - accuracy: 0.5051 - loss: nan - val_accuracy: 0.5001 - val_loss: nan
# Epoch 9/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.5003 - loss: nan - val_accuracy: 0.5001 - val_loss: nan
# Epoch 10/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 61s 79ms/step - accuracy: 0.4935 - loss: nan - val_accuracy: 0.5001 - val_loss: nan

# %%
def generate_text(prompt, model, tokenizer, max_length=100):
    input_ids = tokenizer.encode(prompt, return_tensors='tf')
    output = model.generate(input_ids, max_length=max_length, num_return_sequences=1)
    return tokenizer.decode(output[0], skip_special_tokens=True)

prompt1 = "The movie was fantastic because"
generated_text1 = gpt2_lm.generate(prompt1, max_length=100)
print("Generated text 1:")
print(generated_text1)

# Generate another text with the same or a different prompt
prompt2 = "The storyline was gripping and"
generated_text2 = gpt2_lm.generate(prompt2, max_length=100)
print("Generated text 2:")
print(generated_text2)
# Out:
# Generated text 1:
# The movie was fantastic because, for a while, it was a bit more like a film about the life of an ordinary man who is forced to live in a small house in the middle of nowhere with his wife and children. He is living a simple life, which he does in a house with no plumbing, no electricity and no electricity, but he does have his own bathroom. He is living with his family and his own friends, his family, his family, his family, but he does
# Generated text 2:
# The storyline was gripping and the characters were great. I was very happy with the way they were presented and I think that was really what helped us get there.
#
# I think there's a lot of people that want to play the same character in a different way, and I think that's really what we're doing. I think it's a really good way of doing it for a lot of reasons.
#
# The story is about how the world is changing and how the people in that

# %%
# prompt: creating the interface and launching for the above model

from ipywidgets import Text, Button, VBox

# Create the input and output widgets
input_widget = Text(description="Prompt:")
output_widget = Text(description="Generated Text:")

# Create the button widget
button_widget = Button(description="Generate")

# Create the layout for the widgets
layout = VBox(children=[input_widget, button_widget, output_widget])

# Define the function to generate text when the button is clicked
def generate_text(button):
    prompt = input_widget.value
    generated_text = gpt2_lm.generate(prompt, max_length=100)
    output_widget.value = generated_text

# Connect the button click event to the generate_text function
button_widget.on_click(generate_text)

# Display the widgets
display(layout)
# Out:
# VBox(children=(Text(value='', description='Prompt:'), Button(description='Generate', style=ButtonStyle()), Tex…

# %%
# Use a string identifier.
gpt2_lm.compile(sampler="top_k")
output = gpt2_lm.generate("I like basketball", max_length=200)
print("\nGPT-2 output:")
print(output)

# Use a `Sampler` instance. `GreedySampler` tends to repeat itself,
greedy_sampler = keras_nlp.samplers.GreedySampler()
gpt2_lm.compile(sampler=greedy_sampler)

output = gpt2_lm.generate("I like basketball", max_length=200)
print("\nGPT-2 output:")
print(output)
# Out:
# GPT-2 output:
# I like basketball, and I'm not sure if I'll ever get into the same situation as the Celtics.
#
# They're the Celtics, and they're not a bad team at all; they have the best offensive and defensive record in the NBA, and they've won three straight. They've won four games, they've won five, and they've won six.
#
# I'm sure there's some sort of logic to that, but I'm not going to go there.
#
# But there's a lot of people in the Celtics organization who have been very critical of their team's defense.
#
# I know a lot of people who've seen the film and watched it.
#
# They have been critical, too. They've been critical of their offense in the last five games. They've been critical of the defense, and they've been critical of the offense in the last five games.
#
# So there's no doubt there's some kind of logic to that.
#
# GPT-2 output:
# I like basketball. I like to play it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to watch it. I like to

# %%
!# Load chinese poetry dataset.
# !git clone https://github.com/chinese-poetry/chinese-poetry.git
# Out:
# Cloning into 'chinese-poetry'...
# remote: Enumerating objects: 7315, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 7315 (delta 2), reused 6 (delta 2), pack-reused 7309
# Receiving objects: 100% (7315/7315), 236.97 MiB | 25.10 MiB/s, done.
# Resolving deltas: 100% (5000/5000), done.
# Updating files: 100% (2285/2285), done.

# %%
import os
import json

poem_collection = []
for file in os.listdir("chinese-poetry/全唐诗"):
    if ".json" not in file or "poet" not in file:
        continue
    full_filename = "%s/%s" % ("chinese-poetry/全唐诗", file)
    with open(full_filename, "r") as f:
        content = json.load(f)
        poem_collection.extend(content)

paragraphs = ["".join(data["paragraphs"]) for data in poem_collection]

# %%
print(paragraphs[0])
# Out:
# 摇落秋風急，蕭條易水寒。悲歌誰激烈，宵雅自平寬。本道尊中國，何庸伐可汗。山居聞備塞，莫厭腐儒餐。

# %%
train_ds = (
    tf.data.Dataset.from_tensor_slices(paragraphs)
    .batch(16)
    .cache()
    .prefetch(tf.data.AUTOTUNE)
)

# Running through the whole dataset takes long, only take `500` and run 1
# epochs for demo purposes.
train_ds = train_ds.take(500)
num_epochs = 1

learning_rate = keras.optimizers.schedules.PolynomialDecay(
    5e-4,
    decay_steps=train_ds.cardinality() * num_epochs,
    end_learning_rate=0.0,
)
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
gpt2_lm.compile(
    optimizer=keras.optimizers.Adam(learning_rate),
    loss=loss,
    weighted_metrics=["accuracy"],
)

gpt2_lm.fit(train_ds, epochs=num_epochs)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 143s 233ms/step - accuracy: 0.2418 - loss: 2.8636

# %%
output = gpt2_lm.generate("万字符是很酷的男孩", max_length=200)
print(output)
# Out:
# 万字符是很酷的男孩，時時時望邊花白紅。風風雲秋塵時時，書花馬埃聲堪頭。
